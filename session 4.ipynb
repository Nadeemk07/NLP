# %% [markdown]
# # simple text classification

# %%
import nltk

# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
gender_features('Chandler')
# Out:
# {'last_letter': 'r'}

# %%
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\WELCOME\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\names.zip.
# True

# %%
from nltk.corpus import names
len(names.words())
# Out:
# 7944

# %%
type(names)
# Out:
# nltk.corpus.reader.wordlist.WordListCorpusReader

# %%
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
#  'Aime',
#  'Aimee',
#  'Aimil',
#  'Aina',
#  'Aindrea',
#  'Ainslee',
#  'Ainsley',
#  'Ainslie',
#  'Ajay',
#  'Alaine',
#  'Alameda',
#  'Alana',
#  'Alanah',
#  'Alane',
#  'Alanna',
#  'Alayne',
#  'Alberta',
#  'Albertina',
#  'Albertine',
#  'Albina',
#  'Alecia',
#  'Aleda',
#  'Aleece',
#  'Aleecia',
#  'Aleen',
#  'Alejandra',
#  'Alejandrina',
#  'Alena',
#  'Alene',
#  'Alessandra',
#  'Aleta',
#  'Alethea',
#  'Alex',
#  'Alexa',
#  'Alexandra',
#  'Alexandrina',
#  'Alexi',
#  'Alexia',
#  'Alexina',
#  'Alexine',
#  'Alexis',
#  'Alfie',
#  'Alfreda',
#  'Ali',
#  'Alia',
#  'Alica',
#  'Alice',
#  'Alicea',
#  'Alicia',
#  'Alida',
#  'Alidia',
#  'Alina',
#  'Aline',
#  'Alis',
#  'Alisa',
#  'Alisha',
#  'Alison',
#  'Alissa',
#  'Alisun',
#  'Alix',
#  'Aliza',
#  'Alla',
#  'Alleen',
#  'Allegra',
#  'Allene',
#  'Alli',
#  'Allianora',
#  'Allie',
#  'Allina',
#  'Allis',
#  'Allison',
#  'Allissa',
#  'Allsun',
#  'Ally',
#  'Allyce',
#  'Allyn',
#  'Allys',
#  'Allyson',
#  'Alma',
#  'Almeda',
#  'Almeria',
#  'Almeta',
#  'Almira',
#  'Almire',
#  'Aloise',
#  'Aloisia',
#  'Aloysia',
#  'Alpa',
#  'Alta',
#  'Althea',
#  'Alvera',
#  'Alvina',
#  'Alvinia',
#  'Alvira',
#  'Alyce',
#  'Alyda',
#  'Alys',
#  'Alysa',
#  'Alyse',
#  'Alysia',
#  'Alyson',
#  'Alyss',
#  'Alyssa',
#  'Amabel',
#  'Amabelle',
#  'Amalea',
#  'Amalee',
#  'Amaleta',
#  'Amalia',
#  'Amalie',
#  'Amalita',
#  'Amalle',
#  'Amanda',
#  'Amandi',
#  'Amandie',
#  'Amandy',
#  'Amara',
#  'Amargo',
#  'Amata',
#  'Amber',
#  'Amberly',
#  'Ambrosia',
#  'Ambur',
#  'Ame',
#  'Amelia',
#  'Amelie',
#  'Amelina',
#  'Ameline',
#  'Amelita',
#  'Ami',
#  'Amie',
#  'Amity',
#  'Ammamaria',
#  'Amy',
#  'Ana',
#  'Anabel',
#  'Anabella',
#  'Anabelle',
#  'Anais',
#  'Analiese',
#  'Analise',
#  'Anallese',
#  'Anallise',
#  'Anastasia',
#  'Anastasie',
#  'Anastassia',
#  'Anatola',
#  'Andee',
#  'Andi',
#  'Andie',
#  'Andra',
#  'Andrea',
#  'Andreana',
#  'Andree',
#  'Andrei',
#  'Andria',
#  'Andriana',
#  'Andriette',
#  'Andromache',
#  'Andromeda',
#  'Andy',
#  'Anestassia',
#  'Anet',
#  'Anett',
#  'Anetta',
#  'Anette',
#  'Ange',
#  'Angel',
#  'Angela',
#  'Angele',
#  'Angelia',
#  'Angelica',
#  'Angelika',
#  'Angelina',
#  'Angeline',
#  'Angelique',
#  'Angelita',
#  'Angelle',
#  'Angie',
#  'Angil',
#  'Angy',
#  'Ania',
#  'Anica',
#  'Anissa',
#  'Anita',
#  'Anitra',
#  'Anja',
#  'Anjanette',
#  'Anjela',
#  'Ann',
#  'Ann-Mari',
#  'Ann-Marie',
#  'Anna',
#  'Anna-Diana',
#  'Anna-Diane',
#  'Anna-Maria',
#  'Annabal',
#  'Annabel',
#  'Annabela',
#  'Annabell',
#  'Annabella',
#  'Annabelle',
#  'Annadiana',
#  'Annadiane',
#  'Annalee',
#  'Annalena',
#  'Annaliese',
#  'Annalisa',
#  'Annalise',
#  'Annalyse',
#  'Annamari',
#  'Annamaria',
#  'Annamarie',
#  'Anne',
#  'Anne-Corinne',
#  'Anne-Mar',
#  'Anne-Marie',
#  'Annecorinne',
#  'Anneliese',
#  'Annelise',
#  'Annemarie',
#  'Annetta',
#  'Annette',
#  'Anni',
#  'Annice',
#  'Annie',
#  'Annissa',
#  'Annmaria',
#  'Annmarie',
#  'Annnora',
#  'Annora',
#  'Anny',
#  'Anselma',
#  'Ansley',
#  'Anstice',
#  'Anthe',
#  'Anthea',
#  'Anthia',
#  'Antoinette',
#  'Antonella',
#  'Antonetta',
#  'Antonia',
#  'Antonie',
#  'Antonietta',
#  'Antonina',
#  'Anya',
#  'Aphrodite',
#  'Appolonia',
#  'April',
#  'Aprilette',
#  'Ara',
#  'Arabel',
#  'Arabela',
#  'Arabele',
#  'Arabella',
#  'Arabelle',
#  'Arda',
#  'Ardath',
#  'Ardeen',
#  'Ardelia',
#  'Ardelis',
#  'Ardella',
#  'Ardelle',
#  'Arden',
#  'Ardene',
#  'Ardenia',
#  'Ardine',
#  'Ardis',
#  'Ardith',
#  'Ardra',
#  'Ardyce',
#  'Ardys',
#  'Ardyth',
#  'Aretha',
#  'Ariadne',
#  'Ariana',
#  'Arianne',
#  'Aridatha',
#  'Ariel',
#  'Ariela',
#  'Ariella',
#  'Arielle',
#  'Arlana',
#  'Arlee',
#  'Arleen',
#  'Arlen',
#  'Arlena',
#  'Arlene',
#  'Arleta',
#  'Arlette',
#  'Arleyne',
#  'Arlie',
#  'Arliene',
#  'Arlina',
#  'Arlinda',
#  'Arline',
#  'Arly',
#  'Arlyn',
#  'Arlyne',
#  'Aryn',
#  'Ashely',
#  'Ashlee',
#  'Ashleigh',
#  'Ashlen',
#  'Ashley',
#  'Ashli',
#  'Ashlie',
#  'Ashly',
#  'Asia',
#  'Astra',
#  'Astrid',
#  'Astrix',
#  'Atalanta',
#  'Athena',
#  'Athene',
#  'Atlanta',
#  'Atlante',
#  'Auberta',
#  'Aubine',
#  'Aubree',
#  'Aubrette',
#  'Aubrey',
#  'Aubrie',
#  'Aubry',
#  'Audi',
#  'Audie',
#  'Audra',
#  'Audre',
#  'Audrey',
#  'Audrie',
#  'Audry',
#  'Audrye',
#  'Audy',
#  'Augusta',
#  'Auguste',
#  'Augustina',
#  'Augustine',
#  'Aura',
#  'Aurea',
#  'Aurel',
#  'Aurelea',
#  'Aurelia',
#  'Aurelie',
#  'Auria',
#  'Aurie',
#  'Aurilia',
#  'Aurlie',
#  'Auroora',
#  'Aurora',
#  'Aurore',
#  'Austin',
#  'Austina',
#  'Austine',
#  'Ava',
#  'Aveline',
#  'Averil',
#  'Averyl',
#  'Avie',
#  'Avis',
#  'Aviva',
#  'Avivah',
#  'Avril',
#  'Avrit',
#  'Ayn',
#  'Bab',
#  'Babara',
#  'Babette',
#  'Babita',
#  'Babs',
#  'Bambi',
#  'Bambie',
#  'Bamby',
#  'Barb',
#  'Barbabra',
#  'Barbara',
#  'Barbara-Anne',
#  'Barbaraanne',
#  'Barbe',
#  'Barbee',
#  'Barbette',
#  'Barbey',
#  'Barbi',
#  'Barbie',
#  'Barbra',
#  'Barby',
#  'Bari',
#  'Barrie',
#  'Barry',
#  'Basia',
#  'Bathsheba',
#  'Batsheva',
#  'Bea',
#  'Beatrice',
#  'Beatrisa',
#  'Beatrix',
#  'Beatriz',
#  'Beau',
#  'Bebe',
#  'Becca',
#  'Becka',
#  'Becki',
#  'Beckie',
#  'Becky',
#  'Bee',
#  'Beilul',
#  'Beitris',
#  'Bekki',
#  'Bel',
#  'Belia',
#  'Belicia',
#  'Belinda',
#  'Belita',
#  'Bell',
#  'Bella',
#  'Bellamy',
#  'Bellanca',
#  'Belle',
#  'Bellina',
#  'Belva',
#  'Belvia',
#  'Bendite',
#  'Benedetta',
#  'Benedicta',
#  'Benedikta',
#  'Benetta',
#  'Benita',
#  'Benni',
#  'Bennie',
#  'Benny',
#  'Benoite',
#  'Berenice',
#  'Beret',
#  'Berget',
#  'Berna',
#  'Bernadene',
#  'Bernadette',
#  'Bernadina',
#  'Bernadine',
#  'Bernardina',
#  'Bernardine',
#  'Bernelle',
#  'Bernete',
#  'Bernetta',
#  'Bernette',
#  'Berni',
#  'Bernice',
#  'Bernie',
#  'Bernita',
#  'Berny',
#  'Berri',
#  'Berrie',
#  'Berry',
#  'Bert',
#  'Berta',
#  'Berte',
#  'Bertha',
#  'Berthe',
#  'Berti',
#  'Bertie',
#  'Bertina',
#  'Bertine',
#  'Berty',
#  'Beryl',
#  'Beryle',
#  'Bess',
#  'Bessie',
#  'Bessy',
#  'Beth',
#  'Bethanne',
#  'Bethany',
#  'Bethena',
#  'Bethina',
#  'Betsey',
#  'Betsy',
#  'Betta',
#  'Bette',
#  'Bette-Ann',
#  'Betteann',
#  'Betteanne',
#  'Betti',
#  'Bettie',
#  'Bettina',
#  'Bettine',
#  'Betty',
#  'Bettye',
#  'Beulah',
#  'Bev',
#  'Beverie',
#  'Beverlee',
#  'Beverlie',
#  'Beverly',
#  'Bevvy',
#  'Bianca',
#  'Bianka',
#  'Biddy',
#  'Bidget',
#  'Bill',
#  'Billi',
#  'Billie',
#  'Billy',
#  'Binni',
#  'Binnie',
#  'Binny',
#  'Bird',
#  'Birdie',
#  'Birgit',
#  'Birgitta',
#  'Blair',
#  'Blaire',
#  'Blake',
#  'Blakelee',
#  'Blakeley',
#  'Blanca',
#  'Blanch',
#  'Blancha',
#  'Blanche',
#  'Blinni',
#  'Blinnie',
#  'Blinny',
#  'Bliss',
#  'Blisse',
#  'Blithe',
#  'Blondell',
#  'Blondelle',
#  'Blondie',
#  'Blondy',
#  'Blythe',
#  'Bo',
#  'Bobbette',
#  'Bobbi',
#  'Bobbie',
#  'Bobby',
#  'Bobette',
#  'Bobina',
#  'Bobine',
#  'Bobinette',
#  'Bonita',
#  'Bonnee',
#  'Bonni',
#  'Bonnie',
#  'Bonny',
#  'Brana',
#  'Brandais',
#  'Brande',
#  'Brandea',
#  'Brandi',
#  'Brandice',
#  'Brandie',
#  'Brandise',
#  'Brandy',
#  'Brea',
#  'Breanne',
#  'Brear',
#  'Bree',
#  'Breena',
#  'Bren',
#  'Brena',
#  'Brenda',
#  'Brenn',
#  'Brenna',
#  'Brett',
#  'Bria',
#  'Briana',
#  'Brianna',
#  'Brianne',
#  'Bride',
#  'Bridget',
#  'Bridgett',
#  'Bridgette',
#  'Bridie',
#  'Brier',
#  'Brietta',
#  'Brigid',
#  'Brigida',
#  'Brigit',
#  'Brigitta',
#  'Brigitte',
#  'Brina',
#  'Briney',
#  'Briny',
#  'Brit',
#  'Brita',
#  'Britaney',
#  'Britani',
#  'Briteny',
#  'Britney',
#  'Britni',
#  'Britt',
#  'Britta',
#  'Brittan',
#  'Brittany',
#  'Britte',
#  'Brittney',
#  'Brook',
#  'Brooke',
#  'Brooks',
#  'Brunella',
#  'Brunhilda',
#  'Brunhilde',
#  'Bryana',
#  'Bryn',
#  'Bryna',
#  'Brynn',
#  'Brynna',
#  'Brynne',
#  'Buffy',
#  'Bunni',
#  'Bunnie',
#  'Bunny',
#  'Burta',
#  'Cabrina',
#  'Cacilia',
#  'Cacilie',
#  'Caitlin',
#  'Caitrin',
#  'Cal',
#  'Calida',
#  'Calla',
#  'Calley',
#  'Calli',
#  'Callida',
#  'Callie',
#  'Cally',
#  'Calypso',
#  'Cam',
#  'Camala',
#  'Camel',
#  'Camella',
#  'Camellia',
#  'Cameo',
#  'Cami',
#  'Camila',
#  'Camile',
#  'Camilla',
#  'Camille',
#  'Cammi',
#  'Cammie',
#  'Cammy',
#  'Canada',
#  'Candace',
#  'Candi',
#  'Candice',
#  'Candida',
#  'Candide',
#  'Candie',
#  'Candis',
#  'Candra',
#  'Candy',
#  'Cappella',
#  'Caprice',
#  'Cara',
#  'Caralie',
#  'Caren',
#  'Carena',
#  'Caresa',
#  'Caressa',
#  'Caresse',
#  'Carey',
#  'Cari',
#  'Caria',
#  'Carie',
#  'Caril',
#  'Carilyn',
#  'Carin',
#  'Carina',
#  'Carine',
#  'Cariotta',
#  'Carissa',
#  'Carita',
#  'Caritta',
#  'Carla',
#  'Carlee',
#  'Carleen',
#  'Carlen',
#  'Carlena',
#  'Carlene',
#  'Carley',
#  'Carli',
#  'Carlie',
#  'Carlin',
#  'Carlina',
#  'Carline',
#  'Carlisle',
#  'Carlita',
#  'Carlota',
#  'Carlotta',
#  'Carly',
#  'Carlye',
#  'Carlyn',
#  'Carlynn',
#  'Carlynne',
#  'Carma',
#  'Carmel',
#  'Carmela',
#  'Carmelia',
#  'Carmelina',
#  'Carmelita',
#  'Carmella',
#  'Carmelle',
#  'Carmen',
#  'Carmina',
#  'Carmine',
#  'Carmita',
#  'Carmon',
#  'Caro',
#  'Carol',
#  'Carol-Jean',
#  'Carola',
#  'Carolan',
#  'Carolann',
#  'Carole',
#  'Carolee',
#  'Caroleen',
#  'Carolie',
#  'Carolin',
#  'Carolina',
#  'Caroline',
#  'Caroljean',
#  'Carolyn',
#  'Carolyne',
#  'Carolynn',
#  'Caron',
#  'Carree',
#  'Carri',
#  'Carrie',
#  'Carrissa',
#  'Carrol',
#  'Carroll',
#  'Carry',
#  'Cary',
#  'Caryl',
#  'Caryn',
#  'Casandra',
#  'Casey',
#  'Casi',
#  'Casia',
#  'Casie',
#  'Cass',
#  'Cassandra',
#  'Cassandre',
#  'Cassandry',
#  'Cassaundra',
#  'Cassey',
#  'Cassi',
#  'Cassie',
#  'Cassondra',
#  'Cassy',
#  'Cat',
#  'Catarina',
#  'Cate',
#  'Caterina',
#  'Catha',
#  'Catharina',
#  'Catharine',
#  'Cathe',
#  'Cathee',
#  'Catherin',
#  'Catherina',
#  'Catherine',
#  'Cathi',
#  'Cathie',
#  'Cathleen',
#  'Cathlene',
#  'Cathrin',
#  'Cathrine',
#  'Cathryn',
#  'Cathy',
#  'Cathyleen',
#  'Cati',
#  'Catie',
#  'Catina',
#  'Catlaina',
#  'Catlee',
#  'Catlin',
#  'Catrina',
#  'Catriona',
#  'Caty',
#  'Cayla',
#  'Cecelia',
#  'Cecil',
#  'Cecile',
#  'Ceciley',
#  'Cecilia',
#  'Cecilla',
#  'Cecily',
#  'Ceil',
#  'Cele',
#  'Celene',
#  'Celesta',
#  'Celeste',
#  'Celestia',
#  'Celestina',
#  'Celestine',
#  'Celestyn',
#  'Celestyna',
#  'Celia',
#  'Celie',
#  'Celina',
#  'Celinda',
#  'Celine',
#  'Celinka',
#  'Celisse',
#  'Celle',
#  'Cesya',
#  'Chad',
#  'Chanda',
#  'Chandal',
#  'Chandra',
#  'Channa',
#  'Chantal',
#  'Chantalle',
#  'Charil',
#  'Charin',
#  'Charis',
#  'Charissa',
#  'Charisse',
#  'Charita',
#  'Charity',
#  'Charla',
#  'Charlean',
#  'Charleen',
#  'Charlena',
#  'Charlene',
#  'Charline',
#  'Charlot',
#  'Charlott',
#  'Charlotta',
#  'Charlotte',
#  'Charmain',
#  'Charmaine',
#  'Charmane',
#  'Charmian',
#  'Charmine',
#  'Charmion',
#  'Charo',
#  'Charyl',
#  'Chastity',
#  'Chelsae',
#  'Chelsea',
#  'Chelsey',
#  'Chelsie',
#  'Chelsy',
#  'Cher',
#  'Chere',
#  'Cherey',
#  'Cheri',
#  'Cherianne',
#  'Cherice',
#  'Cherida',
#  'Cherie',
#  'Cherilyn',
#  'Cherilynn',
#  'Cherin',
#  'Cherise',
#  'Cherish',
#  'Cherlyn',
#  'Cherri',
#  'Cherrita',
#  'Cherry',
#  'Chery',
#  'Cherye',
#  'Cheryl',
#  'Cheslie',
#  'Chiarra',
#  'Chickie',
#  'Chicky',
#  'Chiquita',
#  'Chloe',
#  'Chloette',
#  'Chloris',
#  'Chris',
#  'Chriss',
#  'Chrissa',
#  'Chrissie',
#  'Chrissy',
#  'Christa',
#  'Christabel',
#  'Christabella',
#  'Christabelle',
#  'Christal',
#  'Christalle',
#  'Christan',
#  'Christean',
#  'Christel',
#  'Christen',
#  'Christi',
#  'Christian',
#  'Christiana',
#  'Christiane',
#  'Christie',
#  'Christin',
#  'Christina',
#  'Christine',
#  'Christy',
#  'Christyna',
#  'Chrysa',
#  'Chrysler',
#  'Chrystal',
#  'Chryste',
#  'Chrystel',
#  'Ciara',
#  'Cicely',
#  'Cicily',
#  'Ciel',
#  'Cilka',
#  'Cinda',
#  'Cindee',
#  'Cindelyn',
#  'Cinderella',
#  'Cindi',
#  'Cindie',
#  'Cindra',
#  'Cindy',
#  'Cinnamon',
#  'Cissie',
#  'Cissy',
#  'Clair',
#  'Claire',
#  'Clara',
#  'Clarabelle',
#  'Clare',
#  ...]

# %%
labelled_names = [(name, "male") for name in names.words("male.txt")] + [(name, "female") for name in names.words("female.txt")]

# %%
import random
random.shuffle(labelled_names)

# %%
labelled_names
# Out:
# [('Shannah', 'female'),
#  ('Grove', 'male'),
#  ('Antonio', 'male'),
#  ('Ara', 'female'),
#  ('Olenka', 'female'),
#  ('Catharina', 'female'),
#  ('Brenn', 'female'),
#  ('Melisande', 'female'),
#  ('Simone', 'female'),
#  ('Bell', 'female'),
#  ('Francene', 'female'),
#  ('Bernete', 'female'),
#  ('Toddie', 'male'),
#  ('Shandra', 'female'),
#  ('Katine', 'female'),
#  ('Tarra', 'female'),
#  ('Claudina', 'female'),
#  ('Arlee', 'female'),
#  ('Janos', 'male'),
#  ('Janeva', 'female'),
#  ('Melessa', 'female'),
#  ('Emmett', 'male'),
#  ('Lorena', 'female'),
#  ('Esme', 'male'),
#  ('Joycelin', 'female'),
#  ('Sherri', 'female'),
#  ('Rustie', 'male'),
#  ('Leanor', 'female'),
#  ('Cy', 'male'),
#  ('Chauncey', 'male'),
#  ('Nola', 'female'),
#  ('Kaylyn', 'female'),
#  ('Kelvin', 'male'),
#  ('Mercedes', 'female'),
#  ('Quigly', 'male'),
#  ('Rosalie', 'female'),
#  ('Hyacintha', 'female'),
#  ('Rafa', 'female'),
#  ('Dyna', 'female'),
#  ('Audrye', 'female'),
#  ('Guillema', 'female'),
#  ('Lezlie', 'female'),
#  ('Petey', 'male'),
#  ('Lorry', 'female'),
#  ('Harlene', 'female'),
#  ('Osbourn', 'male'),
#  ('Laurella', 'female'),
#  ('Bret', 'male'),
#  ('Danna', 'female'),
#  ('Pavia', 'female'),
#  ('Gregg', 'male'),
#  ('Aina', 'female'),
#  ('Daryn', 'female'),
#  ('Tamiko', 'female'),
#  ('Dorelle', 'female'),
#  ('Edmund', 'male'),
#  ('Alvira', 'female'),
#  ('Tamas', 'male'),
#  ('Sabrina', 'female'),
#  ('Nerte', 'female'),
#  ('Juliane', 'female'),
#  ('Tedmund', 'male'),
#  ('Gilberto', 'male'),
#  ('Wittie', 'male'),
#  ("E'Lane", 'female'),
#  ('Prudence', 'female'),
#  ('Inge', 'female'),
#  ('Tobie', 'male'),
#  ('Marley', 'female'),
#  ('Clo', 'female'),
#  ('Jandy', 'female'),
#  ('Tomiko', 'female'),
#  ('Melloney', 'female'),
#  ('Conway', 'male'),
#  ('Beck', 'male'),
#  ('Laverne', 'female'),
#  ('Benedicta', 'female'),
#  ('Lynnet', 'female'),
#  ('Darrel', 'male'),
#  ('Jermaine', 'female'),
#  ('Christin', 'female'),
#  ('Anjanette', 'female'),
#  ('Cari', 'female'),
#  ('Matteo', 'male'),
#  ('Laird', 'male'),
#  ('Lindi', 'female'),
#  ('Allison', 'female'),
#  ('Candie', 'female'),
#  ('Elwyn', 'male'),
#  ('Drea', 'female'),
#  ('Norman', 'male'),
#  ('Matthaeus', 'male'),
#  ('Ester', 'female'),
#  ('Yancey', 'male'),
#  ('Clementine', 'female'),
#  ('Celia', 'female'),
#  ('Dulcy', 'female'),
#  ('Marthe', 'female'),
#  ('Chelsey', 'female'),
#  ('Dixie', 'female'),
#  ('Roseann', 'female'),
#  ('Allyce', 'female'),
#  ('Rey', 'female'),
#  ('Kirstyn', 'female'),
#  ('Annalise', 'female'),
#  ('Dita', 'female'),
#  ('Arianne', 'female'),
#  ('Gav', 'male'),
#  ('Carissa', 'female'),
#  ('Rosita', 'female'),
#  ('Catie', 'female'),
#  ('Moses', 'male'),
#  ('Julietta', 'female'),
#  ('Deidre', 'female'),
#  ('Yacov', 'male'),
#  ('Willey', 'male'),
#  ('Nicolle', 'female'),
#  ('Katherina', 'female'),
#  ('Meridel', 'female'),
#  ('Horace', 'male'),
#  ('Donna', 'female'),
#  ('Charlene', 'female'),
#  ('Erica', 'female'),
#  ('Kinna', 'female'),
#  ('Jeffie', 'male'),
#  ('Dew', 'female'),
#  ('Rene', 'male'),
#  ('Callida', 'female'),
#  ('Celie', 'female'),
#  ('Ismail', 'male'),
#  ('Celine', 'female'),
#  ('Kenn', 'male'),
#  ('Carolin', 'female'),
#  ('Modestia', 'female'),
#  ('Nanice', 'female'),
#  ('Gonzalo', 'male'),
#  ('Winny', 'male'),
#  ('Rinaldo', 'male'),
#  ('Barnabe', 'male'),
#  ('Melvyn', 'male'),
#  ('Canada', 'female'),
#  ('Tonya', 'female'),
#  ('Alisa', 'female'),
#  ('Baily', 'male'),
#  ('Casie', 'female'),
#  ('Casandra', 'female'),
#  ('Silvester', 'male'),
#  ('Nance', 'female'),
#  ('Gray', 'female'),
#  ('Janina', 'female'),
#  ('Appolonia', 'female'),
#  ('Gennifer', 'female'),
#  ('Ronnie', 'female'),
#  ('Kevina', 'female'),
#  ('Faina', 'female'),
#  ('Seamus', 'male'),
#  ('Perry', 'male'),
#  ('Flin', 'male'),
#  ('Grace', 'female'),
#  ('Smitty', 'male'),
#  ('Cissy', 'female'),
#  ('Gabbie', 'female'),
#  ('Lazar', 'male'),
#  ('Martainn', 'male'),
#  ('Marietta', 'male'),
#  ('Shandie', 'female'),
#  ('Stevana', 'female'),
#  ('Jimbo', 'male'),
#  ('Fawn', 'female'),
#  ('Emalee', 'female'),
#  ('Paolina', 'female'),
#  ('Jerry', 'male'),
#  ('Micheal', 'male'),
#  ('Jervis', 'male'),
#  ('Alf', 'male'),
#  ('Kristal', 'female'),
#  ('Laetitia', 'female'),
#  ('Son', 'male'),
#  ('Coralyn', 'female'),
#  ('Desaree', 'female'),
#  ('Bartolomeo', 'male'),
#  ('Claribel', 'female'),
#  ('Verene', 'female'),
#  ('Sussi', 'female'),
#  ('Eunice', 'female'),
#  ('Clark', 'male'),
#  ('Norrie', 'female'),
#  ('Gloria', 'female'),
#  ('Benedict', 'male'),
#  ('Diana', 'female'),
#  ('Stearne', 'male'),
#  ('Dedie', 'female'),
#  ('Raynard', 'male'),
#  ('Malanie', 'female'),
#  ('Emmet', 'male'),
#  ('Lynnea', 'female'),
#  ('Sid', 'male'),
#  ('Corrie', 'female'),
#  ('Malina', 'female'),
#  ('Acacia', 'female'),
#  ('Federico', 'male'),
#  ('Antonella', 'female'),
#  ('Doll', 'female'),
#  ('Karena', 'female'),
#  ('Aigneis', 'female'),
#  ('Carie', 'female'),
#  ('Francois', 'male'),
#  ('Carolann', 'female'),
#  ('Whitney', 'female'),
#  ('Nathalie', 'female'),
#  ('Lex', 'male'),
#  ('Bing', 'male'),
#  ('Geof', 'male'),
#  ('Fay', 'female'),
#  ('Gershom', 'male'),
#  ('Delinda', 'female'),
#  ('Timmy', 'female'),
#  ('Vanni', 'female'),
#  ('Catherine', 'female'),
#  ('Howie', 'male'),
#  ('Shirline', 'female'),
#  ('Hiralal', 'male'),
#  ('Munmro', 'male'),
#  ('Neddy', 'male'),
#  ('Stanfield', 'male'),
#  ('Othella', 'female'),
#  ('Alfreda', 'female'),
#  ('Calypso', 'female'),
#  ('Pattie', 'male'),
#  ('Tarrah', 'female'),
#  ('Mariya', 'female'),
#  ('Quint', 'male'),
#  ('Allah', 'male'),
#  ('Raine', 'female'),
#  ('Tye', 'male'),
#  ('Tammie', 'male'),
#  ('Oren', 'male'),
#  ('Pierce', 'male'),
#  ('Veronique', 'female'),
#  ('Orelia', 'female'),
#  ('Consolata', 'female'),
#  ('Farrah', 'female'),
#  ('Adolpho', 'male'),
#  ('Lazarus', 'male'),
#  ('Bradley', 'male'),
#  ('Elspeth', 'female'),
#  ('Claudia', 'female'),
#  ('Lani', 'female'),
#  ('Herrick', 'male'),
#  ('Ileane', 'female'),
#  ('Donella', 'female'),
#  ('Datha', 'female'),
#  ('Susette', 'female'),
#  ('Adele', 'female'),
#  ('Lanita', 'female'),
#  ('Leia', 'female'),
#  ('Nike', 'female'),
#  ('Valdemar', 'male'),
#  ('Nevins', 'male'),
#  ('Suzi', 'female'),
#  ('Pepillo', 'male'),
#  ('Opalina', 'female'),
#  ('Tiphani', 'female'),
#  ('Marigold', 'female'),
#  ('Basil', 'male'),
#  ('Shellie', 'female'),
#  ('Debora', 'female'),
#  ('Torre', 'male'),
#  ('Nevile', 'male'),
#  ('Norean', 'female'),
#  ('Milly', 'female'),
#  ('Elsey', 'female'),
#  ('Nertie', 'female'),
#  ('Caroline', 'female'),
#  ('Mindy', 'female'),
#  ('Terrye', 'female'),
#  ('Thedrick', 'male'),
#  ('Ermentrude', 'female'),
#  ('Moina', 'female'),
#  ('Tybie', 'female'),
#  ('Viviyan', 'female'),
#  ('Astra', 'female'),
#  ('Elane', 'female'),
#  ('Philip', 'male'),
#  ('Kristine', 'female'),
#  ('Paco', 'male'),
#  ('Leela', 'female'),
#  ('Peri', 'female'),
#  ('Lydie', 'female'),
#  ('Teodoro', 'male'),
#  ('Carlisle', 'female'),
#  ('Joyan', 'female'),
#  ('Wallace', 'male'),
#  ('Donny', 'female'),
#  ('Maren', 'female'),
#  ('Aldwin', 'male'),
#  ('Catha', 'female'),
#  ('Meredeth', 'male'),
#  ('Merell', 'male'),
#  ('Ashlee', 'female'),
#  ('Myrna', 'female'),
#  ('Woodrow', 'male'),
#  ('Beitris', 'female'),
#  ('Zed', 'male'),
#  ('Hannie', 'female'),
#  ('Sharity', 'female'),
#  ('Theressa', 'female'),
#  ('Giraud', 'male'),
#  ('Cleland', 'male'),
#  ('Desiree', 'female'),
#  ('Margurite', 'female'),
#  ('Rich', 'male'),
#  ('Pamela', 'female'),
#  ('Corabella', 'female'),
#  ('Maryjo', 'female'),
#  ('Alejandrina', 'female'),
#  ('Gardner', 'male'),
#  ('Arvie', 'male'),
#  ('Yale', 'male'),
#  ('Sascha', 'female'),
#  ('Charo', 'female'),
#  ('Cate', 'female'),
#  ('Kirby', 'male'),
#  ('Town', 'male'),
#  ('Grover', 'male'),
#  ('Teresa', 'female'),
#  ('Devondra', 'female'),
#  ('Alton', 'male'),
#  ('Marit', 'female'),
#  ('Odele', 'female'),
#  ('Susannah', 'female'),
#  ('Belva', 'female'),
#  ('Wynne', 'female'),
#  ('Baxter', 'male'),
#  ('Abel', 'male'),
#  ('Timmi', 'female'),
#  ('Socrates', 'male'),
#  ('Davita', 'female'),
#  ('Aile', 'female'),
#  ('Beaufort', 'male'),
#  ('Ivor', 'male'),
#  ('Coral', 'female'),
#  ('Merissa', 'female'),
#  ('Abbott', 'male'),
#  ('Denyse', 'female'),
#  ('Maura', 'female'),
#  ('Antonie', 'female'),
#  ('Minnie', 'female'),
#  ('Forest', 'male'),
#  ('Ericha', 'female'),
#  ('Marianna', 'female'),
#  ('Darsey', 'female'),
#  ('Isador', 'female'),
#  ('Mathilda', 'female'),
#  ('Sissie', 'female'),
#  ('Joyann', 'female'),
#  ('Andree', 'female'),
#  ('Ezra', 'male'),
#  ('Giovanne', 'male'),
#  ('Vina', 'female'),
#  ('Dodi', 'female'),
#  ('Alexia', 'female'),
#  ('Laurianne', 'female'),
#  ('Melva', 'female'),
#  ('Camellia', 'female'),
#  ('Joleen', 'female'),
#  ('Pembroke', 'male'),
#  ('Roxanna', 'female'),
#  ('Audra', 'female'),
#  ('Brynn', 'female'),
#  ('Sheena', 'female'),
#  ('Brandi', 'female'),
#  ('Wolfram', 'male'),
#  ('Farley', 'male'),
#  ('August', 'male'),
#  ('Danyette', 'female'),
#  ('Filmore', 'male'),
#  ('Annamarie', 'female'),
#  ('Noam', 'male'),
#  ('Meriel', 'female'),
#  ('Sue-elle', 'female'),
#  ('Martica', 'female'),
#  ('Melanie', 'female'),
#  ('Julita', 'female'),
#  ('Darryl', 'male'),
#  ('Sheffy', 'male'),
#  ('Anatola', 'female'),
#  ('Juliet', 'female'),
#  ('Shandy', 'female'),
#  ('Daren', 'male'),
#  ('Melissa', 'female'),
#  ('Babette', 'female'),
#  ('Kostas', 'male'),
#  ('Ethel', 'female'),
#  ('Janene', 'female'),
#  ('Clair', 'female'),
#  ('Marcelline', 'female'),
#  ('Lyn', 'male'),
#  ('Waylin', 'male'),
#  ('Sela', 'female'),
#  ('Dorthy', 'female'),
#  ('Garfield', 'male'),
#  ('Randi', 'female'),
#  ('Evaleen', 'female'),
#  ('Farica', 'female'),
#  ('Virgie', 'male'),
#  ('Willy', 'female'),
#  ('Andriette', 'female'),
#  ('Wakefield', 'male'),
#  ('Theresa', 'female'),
#  ('Bernice', 'female'),
#  ('Berri', 'female'),
#  ('Patrice', 'male'),
#  ('Nona', 'female'),
#  ('Elysha', 'female'),
#  ('Ivory', 'female'),
#  ('Roy', 'male'),
#  ('Wilie', 'female'),
#  ('Claybourne', 'male'),
#  ('Linda', 'female'),
#  ('Camile', 'female'),
#  ('Nannie', 'female'),
#  ('Angus', 'male'),
#  ('Nathanial', 'male'),
#  ('Celinda', 'female'),
#  ('Lazare', 'male'),
#  ('Laurie', 'male'),
#  ('Waly', 'female'),
#  ('Arnold', 'male'),
#  ('Vivyanne', 'female'),
#  ('Pinchas', 'male'),
#  ('Gunvor', 'female'),
#  ('Barnaby', 'male'),
#  ('Natty', 'female'),
#  ('Karolina', 'female'),
#  ('Barty', 'male'),
#  ('Brett', 'male'),
#  ('Leslie', 'female'),
#  ('Brande', 'female'),
#  ('Frances', 'female'),
#  ('Barnebas', 'male'),
#  ('Sim', 'male'),
#  ('Tedd', 'male'),
#  ('Bobette', 'female'),
#  ('Ross', 'male'),
#  ('Kesley', 'female'),
#  ('Riane', 'female'),
#  ('Julissa', 'female'),
#  ('Les', 'male'),
#  ('Carey', 'female'),
#  ('Wilt', 'male'),
#  ('Cleva', 'female'),
#  ('Agnesse', 'female'),
#  ('Eleanor', 'female'),
#  ('Emlyn', 'female'),
#  ('Lucian', 'male'),
#  ('Cristopher', 'male'),
#  ('Elbertine', 'female'),
#  ('Ollie', 'female'),
#  ('Jerold', 'male'),
#  ('Brana', 'female'),
#  ('Harriott', 'female'),
#  ('Allyn', 'female'),
#  ('Flossie', 'female'),
#  ('Bethena', 'female'),
#  ('Ronnica', 'female'),
#  ('Vic', 'male'),
#  ('Von', 'male'),
#  ('Dickey', 'male'),
#  ('Levy', 'male'),
#  ('Sherwynd', 'male'),
#  ('Tessa', 'female'),
#  ('Jacynth', 'female'),
#  ('Joya', 'female'),
#  ('Keriann', 'female'),
#  ('Ginger', 'male'),
#  ('Latia', 'female'),
#  ('Goddart', 'male'),
#  ('Aurel', 'female'),
#  ('Jere', 'male'),
#  ('Greggory', 'male'),
#  ('Judd', 'male'),
#  ('Aindrea', 'female'),
#  ('Stanton', 'male'),
#  ('Gwennie', 'female'),
#  ('Betsy', 'female'),
#  ('Reggie', 'male'),
#  ('Elisabet', 'female'),
#  ('Niles', 'male'),
#  ('Trudey', 'female'),
#  ('Stormie', 'female'),
#  ('Denny', 'female'),
#  ('Chickie', 'female'),
#  ('Albert', 'male'),
#  ('Cornelle', 'female'),
#  ('Eran', 'female'),
#  ('Margit', 'female'),
#  ('Maribel', 'female'),
#  ('Suzan', 'female'),
#  ('Riva', 'female'),
#  ('Gwendolin', 'female'),
#  ('Cosmo', 'male'),
#  ('Angele', 'female'),
#  ('Lynnell', 'female'),
#  ('Valeria', 'female'),
#  ('Pepi', 'female'),
#  ('Xylina', 'female'),
#  ('Yance', 'male'),
#  ('Sibyl', 'female'),
#  ('Penelope', 'female'),
#  ('Britani', 'female'),
#  ('Erena', 'female'),
#  ('Ludwig', 'male'),
#  ('Samantha', 'female'),
#  ('Nert', 'female'),
#  ('Bela', 'male'),
#  ('Thia', 'female'),
#  ('Binny', 'female'),
#  ('Gilbertine', 'female'),
#  ('Daisi', 'female'),
#  ('Hamish', 'male'),
#  ('Adah', 'female'),
#  ('Shawna', 'female'),
#  ('Pandora', 'female'),
#  ('Ardella', 'female'),
#  ('Douggie', 'male'),
#  ('Helene', 'female'),
#  ('Hari', 'male'),
#  ('Durward', 'male'),
#  ('Pietro', 'male'),
#  ('Kassi', 'female'),
#  ('Shadow', 'male'),
#  ('Deborah', 'female'),
#  ('Donald', 'male'),
#  ('Dwight', 'male'),
#  ('Meyer', 'male'),
#  ('Marlin', 'male'),
#  ('Tessi', 'female'),
#  ('Christabelle', 'female'),
#  ('Constantina', 'female'),
#  ('Dorolice', 'female'),
#  ('Sibilla', 'female'),
#  ('Kathlene', 'female'),
#  ('Janine', 'female'),
#  ('Sonnie', 'male'),
#  ('Gleda', 'female'),
#  ('Bruce', 'male'),
#  ('Cassaundra', 'female'),
#  ('Christal', 'female'),
#  ('Darcie', 'female'),
#  ('Kingsly', 'male'),
#  ('Lothar', 'male'),
#  ('Blair', 'female'),
#  ('Belvia', 'female'),
#  ('Allina', 'female'),
#  ('Constantia', 'female'),
#  ('Lind', 'female'),
#  ('Mari', 'female'),
#  ('Katey', 'female'),
#  ('Annissa', 'female'),
#  ('Patric', 'male'),
#  ('Karola', 'female'),
#  ('Nisse', 'female'),
#  ('Alwin', 'male'),
#  ('Osbourne', 'male'),
#  ('Oliy', 'female'),
#  ('Avram', 'male'),
#  ('Buster', 'male'),
#  ('Zebedee', 'male'),
#  ('Tomasine', 'female'),
#  ('Layney', 'female'),
#  ('Guy', 'male'),
#  ('Giana', 'female'),
#  ('Loree', 'female'),
#  ('Micheline', 'female'),
#  ('Arabelle', 'female'),
#  ('Guillaume', 'male'),
#  ('Geoffrey', 'male'),
#  ('Parrnell', 'male'),
#  ('Lisha', 'female'),
#  ('Tracee', 'female'),
#  ('Ruddy', 'male'),
#  ('Sax', 'male'),
#  ('Anabella', 'female'),
#  ('Niki', 'female'),
#  ('Tommie', 'male'),
#  ('Erick', 'male'),
#  ('Nataline', 'female'),
#  ('Gilli', 'female'),
#  ('Nova', 'female'),
#  ('Genevieve', 'female'),
#  ('Angil', 'female'),
#  ('Pauli', 'female'),
#  ('Lauree', 'female'),
#  ('Don', 'male'),
#  ('Avis', 'female'),
#  ('Cal', 'female'),
#  ('Marion', 'female'),
#  ('Robin', 'female'),
#  ('Wait', 'male'),
#  ('Esmerelda', 'female'),
#  ('Zorine', 'female'),
#  ('Murial', 'female'),
#  ('Randi', 'male'),
#  ('Beilul', 'female'),
#  ('Lilla', 'female'),
#  ('Kippy', 'female'),
#  ('Renaldo', 'male'),
#  ('Chane', 'male'),
#  ('Carlynne', 'female'),
#  ('Gusella', 'female'),
#  ('Janenna', 'female'),
#  ('Wildon', 'male'),
#  ('Prentiss', 'male'),
#  ('Lora', 'female'),
#  ('Bernadette', 'female'),
#  ('Marga', 'female'),
#  ('June', 'female'),
#  ('Cassey', 'female'),
#  ('Edee', 'female'),
#  ('Eda', 'female'),
#  ('Vanna', 'female'),
#  ('Rochester', 'male'),
#  ('Janeen', 'female'),
#  ('Annie', 'female'),
#  ('Jo-Anne', 'female'),
#  ('Diann', 'female'),
#  ('Denice', 'female'),
#  ('Benny', 'female'),
#  ('Ernesto', 'male'),
#  ('Jedediah', 'male'),
#  ('Fan', 'female'),
#  ('Bay', 'male'),
#  ('Gerome', 'male'),
#  ('Roch', 'female'),
#  ('Sosanna', 'female'),
#  ('Lurline', 'female'),
#  ('Cally', 'female'),
#  ('Lucita', 'female'),
#  ('Clarence', 'male'),
#  ('Scottie', 'male'),
#  ('Neysa', 'female'),
#  ('Patrice', 'female'),
#  ('Nedi', 'female'),
#  ('Windy', 'female'),
#  ('Ardeen', 'female'),
#  ('Nissie', 'female'),
#  ('Cilka', 'female'),
#  ('Rodina', 'female'),
#  ('Mace', 'male'),
#  ('Leola', 'female'),
#  ('Lorinda', 'female'),
#  ('Marlo', 'male'),
#  ('Lindsay', 'female'),
#  ('Morlee', 'male'),
#  ('Elenore', 'female'),
#  ('Audie', 'female'),
#  ('Wylma', 'female'),
#  ('Gipsy', 'female'),
#  ('Montague', 'male'),
#  ('Jeanne', 'female'),
#  ('Marj', 'female'),
#  ('Perrine', 'female'),
#  ('Ulrika', 'female'),
#  ('Weston', 'male'),
#  ('Sunny', 'female'),
#  ('Hyatt', 'male'),
#  ('Dido', 'female'),
#  ('Sonny', 'male'),
#  ('Moishe', 'male'),
#  ('Edita', 'female'),
#  ('Joyce', 'female'),
#  ('Hunter', 'male'),
#  ('Andrew', 'male'),
#  ('Stig', 'male'),
#  ('Barbabra', 'female'),
#  ('Erich', 'male'),
#  ('Lindsey', 'female'),
#  ('Kate', 'female'),
#  ('Kirbie', 'female'),
#  ('Hannibal', 'male'),
#  ('Karil', 'female'),
#  ('Bernadina', 'female'),
#  ('Cherida', 'female'),
#  ('Kaspar', 'male'),
#  ('Sumner', 'male'),
#  ('Ferdie', 'male'),
#  ('Selma', 'female'),
#  ('Daria', 'female'),
#  ('Abbey', 'male'),
#  ('Bennet', 'male'),
#  ('Danit', 'female'),
#  ('French', 'male'),
#  ('Katuscha', 'female'),
#  ('Debby', 'female'),
#  ('Aili', 'female'),
#  ('Sherrie', 'female'),
#  ('Annabal', 'female'),
#  ('Way', 'male'),
#  ('Smith', 'male'),
#  ('Bharat', 'male'),
#  ('Vonny', 'female'),
#  ('Dove', 'female'),
#  ('Binky', 'male'),
#  ('Malkah', 'female'),
#  ('Maurine', 'female'),
#  ('Tannie', 'male'),
#  ('Tanner', 'male'),
#  ('Kariotta', 'female'),
#  ('Raychel', 'female'),
#  ('Jobey', 'female'),
#  ('Daphna', 'female'),
#  ('Orton', 'male'),
#  ('Angelita', 'female'),
#  ('Freddi', 'female'),
#  ('Hermine', 'female'),
#  ('Dawn', 'female'),
#  ('Hirsch', 'male'),
#  ('Neila', 'female'),
#  ('Anetta', 'female'),
#  ('Johanna', 'female'),
#  ('Nelia', 'female'),
#  ('Auria', 'female'),
#  ('Michaelina', 'female'),
#  ('Gussie', 'female'),
#  ('Cheri', 'female'),
#  ('Stacy', 'male'),
#  ('Husain', 'male'),
#  ('Mollie', 'female'),
#  ('Jennette', 'female'),
#  ('Lion', 'male'),
#  ('Odella', 'female'),
#  ('Lynna', 'female'),
#  ('Beverie', 'female'),
#  ('Bridget', 'female'),
#  ('Marysa', 'female'),
#  ('Roscoe', 'male'),
#  ('Elmira', 'female'),
#  ('Florrie', 'female'),
#  ('Kaitlin', 'female'),
#  ('Carolyn', 'female'),
#  ('Erny', 'male'),
#  ('Melvin', 'male'),
#  ('Yettie', 'female'),
#  ('Carlos', 'male'),
#  ('Neall', 'male'),
#  ('Harley', 'female'),
#  ('Thornton', 'male'),
#  ('Sancho', 'male'),
#  ('Sharleen', 'female'),
#  ('Licha', 'female'),
#  ('Ladonna', 'female'),
#  ('Hallie', 'female'),
#  ('Paten', 'male'),
#  ('Torie', 'female'),
#  ('Susana', 'female'),
#  ('Zorro', 'male'),
#  ('Federica', 'female'),
#  ('Reena', 'female'),
#  ('Una', 'female'),
#  ('Leiah', 'female'),
#  ('Barnett', 'male'),
#  ('Warner', 'male'),
#  ('Misti', 'female'),
#  ('Abagail', 'female'),
#  ('Birdie', 'female'),
#  ('Salomo', 'male'),
#  ('Thadeus', 'male'),
#  ('Rosanne', 'female'),
#  ('Nickolas', 'male'),
#  ('Rogers', 'male'),
#  ('Ophelie', 'female'),
#  ('Kathryn', 'female'),
#  ('Forbes', 'male'),
#  ('Brent', 'male'),
#  ('Leone', 'female'),
#  ('Caralie', 'female'),
#  ('Leeanne', 'female'),
#  ('Averil', 'female'),
#  ('Juditha', 'female'),
#  ('Moselle', 'female'),
#  ('Melicent', 'female'),
#  ('Christian', 'female'),
#  ('Durant', 'male'),
#  ('Cordie', 'female'),
#  ('Spenser', 'male'),
#  ('Faunie', 'female'),
#  ('Dorothy', 'female'),
#  ('Gayleen', 'female'),
#  ('Deanna', 'female'),
#  ('Spud', 'male'),
#  ('Britt', 'male'),
#  ('Derrol', 'male'),
#  ('Andreana', 'female'),
#  ('Cherri', 'female'),
#  ('Frazier', 'male'),
#  ('Cati', 'female'),
#  ('Juli', 'female'),
#  ('Brandy', 'female'),
#  ('Kimmy', 'female'),
#  ('Malinda', 'female'),
#  ('Lucretia', 'female'),
#  ('Allissa', 'female'),
#  ('Rolando', 'male'),
#  ('Sollie', 'male'),
#  ('Faith', 'female'),
#  ('Michel', 'male'),
#  ('Nichol', 'female'),
#  ('Estrella', 'female'),
#  ('Spike', 'male'),
#  ('Leelah', 'female'),
#  ('Staffard', 'male'),
#  ('Tandie', 'female'),
#  ('Winonah', 'female'),
#  ('Pacifica', 'female'),
#  ('Samuella', 'female'),
#  ('Harry', 'male'),
#  ('Karel', 'male'),
#  ('Maire', 'female'),
#  ('Meridith', 'female'),
#  ('Korry', 'female'),
#  ('Quiggly', 'male'),
#  ('Hubert', 'male'),
#  ('Yvonne', 'female'),
#  ('Dell', 'female'),
#  ('Apostolos', 'male'),
#  ('Eileen', 'female'),
#  ('Dabney', 'male'),
#  ('Filippa', 'female'),
#  ('Lemuel', 'male'),
#  ('Sheba', 'female'),
#  ('Doroteya', 'female'),
#  ('Barn', 'male'),
#  ('Franciska', 'female'),
#  ('Corny', 'female'),
#  ('Juan', 'male'),
#  ('Flem', 'male'),
#  ('Neala', 'female'),
#  ('Blithe', 'female'),
#  ('Sully', 'male'),
#  ('Vale', 'female'),
#  ('Bellamy', 'female'),
#  ('Cecilla', 'female'),
#  ('Marlo', 'female'),
#  ('Dasha', 'female'),
#  ('Nicoline', 'female'),
#  ('Curt', 'male'),
#  ('Titos', 'male'),
#  ('Marglerite', 'female'),
#  ('Cathleen', 'female'),
#  ('Juergen', 'male'),
#  ('Mag', 'female'),
#  ('Godfry', 'male'),
#  ('Noella', 'female'),
#  ('Jami', 'female'),
#  ('Sherry', 'female'),
#  ('Henry', 'male'),
#  ('Sturgis', 'male'),
#  ('Luisa', 'female'),
#  ('Johannes', 'male'),
#  ('Chariot', 'male'),
#  ('Barnard', 'male'),
#  ('Griffith', 'male'),
#  ('Yevette', 'female'),
#  ('Justin', 'male'),
#  ('Danny', 'female'),
#  ('Willis', 'male'),
#  ('Dorris', 'female'),
#  ('Ralina', 'female'),
#  ('Ninnette', 'female'),
#  ('Sibeal', 'female'),
#  ('Marie-Jeanne', 'female'),
#  ('Rhoda', 'female'),
#  ('Lynne', 'female'),
#  ('Danell', 'female'),
#  ('Jenni', 'female'),
#  ('Fredra', 'female'),
#  ('Kelsy', 'female'),
#  ('Torrie', 'female'),
#  ('Kraig', 'male'),
#  ('Raul', 'male'),
#  ('Meara', 'female'),
#  ('Anthia', 'female'),
#  ('Eulalie', 'female'),
#  ('Ruperta', 'female'),
#  ('Joscelin', 'female'),
#  ('Georges', 'male'),
#  ('Tammie', 'female'),
#  ('Cordelia', 'female'),
#  ('Pierson', 'male'),
#  ('Shantee', 'female'),
#  ('Florinda', 'female'),
#  ('Emmeline', 'female'),
#  ('Harcourt', 'male'),
#  ('Amelita', 'female'),
#  ('Hedwig', 'female'),
#  ('Harmon', 'male'),
#  ('Brunella', 'female'),
#  ('Duffie', 'male'),
#  ('Vivyan', 'female'),
#  ('Faun', 'female'),
#  ('Peria', 'female'),
#  ('Harley', 'male'),
#  ('Lilli', 'female'),
#  ('Cindelyn', 'female'),
#  ('Gretchen', 'female'),
#  ('Georgette', 'female'),
#  ('Stirling', 'male'),
#  ('Scott', 'male'),
#  ('Calida', 'female'),
#  ('Roshelle', 'female'),
#  ('Blisse', 'female'),
#  ('Dulcinea', 'female'),
#  ('Mufinella', 'female'),
#  ('Claudette', 'female'),
#  ('Bearnard', 'male'),
#  ('Guenevere', 'female'),
#  ('Rica', 'female'),
#  ('Bernardine', 'female'),
#  ('Raquel', 'female'),
#  ('Theodoric', 'male'),
#  ('Christian', 'male'),
#  ('Tiffani', 'female'),
#  ('Gere', 'male'),
#  ('Marylinda', 'female'),
#  ('Jorge', 'male'),
#  ('Ruperto', 'male'),
#  ('Randie', 'female'),
#  ('Dorena', 'female'),
#  ('Chrystal', 'female'),
#  ('Ros', 'female'),
#  ('Nena', 'female'),
#  ('Diandra', 'female'),
#  ('Cob', 'male'),
#  ('Bambie', 'female'),
#  ('Yoshi', 'female'),
#  ('Jayne', 'female'),
#  ('Ashely', 'female'),
#  ('Ashish', 'male'),
#  ('Morgana', 'female'),
#  ('Abdel', 'male'),
#  ('Carita', 'female'),
#  ('Candra', 'female'),
#  ('Delia', 'female'),
#  ('Tabby', 'male'),
#  ('Jonas', 'male'),
#  ('Fortuna', 'female'),
#  ('Caryl', 'female'),
#  ('Katrinka', 'female'),
#  ('Lin', 'male'),
#  ('Katherine', 'female'),
#  ('Jules', 'male'),
#  ('Aron', 'male'),
#  ('Maggi', 'female'),
#  ('Tansy', 'female'),
#  ('Sarge', 'male'),
#  ('Zelda', 'female'),
#  ('Dulce', 'female'),
#  ('Emily', 'female'),
#  ('Shelli', 'female'),
#  ('Rebe', 'female'),
#  ('Tess', 'female'),
#  ('Nikolia', 'female'),
#  ('Guillermo', 'male'),
#  ('Maurits', 'male'),
#  ('Arvy', 'male'),
#  ('Bill', 'male'),
#  ('Angelina', 'female'),
#  ('Aloysius', 'male'),
#  ('Celina', 'female'),
#  ('Carlton', 'male'),
#  ('Timotheus', 'male'),
#  ('Hayes', 'male'),
#  ('Caterina', 'female'),
#  ('Dru', 'male'),
#  ('Alastair', 'male'),
#  ('Edi', 'female'),
#  ('Thaxter', 'male'),
#  ('Penni', 'female'),
#  ('Christabel', 'female'),
#  ('Rheba', 'female'),
#  ('Shoshie', 'female'),
#  ('Ulla', 'female'),
#  ('Vernon', 'male'),
#  ('Dotti', 'female'),
#  ('Malva', 'female'),
#  ('Ewan', 'male'),
#  ('Laraine', 'female'),
#  ('Oscar', 'male'),
#  ('Mikey', 'male'),
#  ('Hobart', 'male'),
#  ('Alan', 'male'),
#  ('Valli', 'female'),
#  ('Marja', 'female'),
#  ('Ruby', 'male'),
#  ('Elwira', 'female'),
#  ('Francisca', 'female'),
#  ('Margaretha', 'female'),
#  ('Archibold', 'male'),
#  ('Willabella', 'female'),
#  ...]

# %%
featuresset = [(gender_features(name), gender) for (name, gender) in labelled_names]
train_set, test_set = featuresset[:6000], featuresset[6001:]

# %%
clf = nltk.NaiveBayesClassifier.train(train_set)

# %%
clf.classify(gender_features("Nadeem"))
# Out:
# 'male'

# %%
clf.classify(gender_features("Ayesha"))
# Out:
# 'female'
